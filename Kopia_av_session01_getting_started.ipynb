# %% [markdown]
# <a href="https://colab.research.google.com/github/aehaf988/CB2330-portfolio/blob/main/Kopia_av_session01_getting_started.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
counts = [1204, 3310, 87, 412, 0, 26]
expressed = [c for c in counts if c >= 100]
print(len(expressed), "of", len(counts), "genes expressed")
print("mean count", sum(expressed) / len(expressed))
# Out:
# 3 of 6 genes expressed
# mean count 1642.0
