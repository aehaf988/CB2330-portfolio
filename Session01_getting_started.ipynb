# %% [markdown]
# <a href="https://colab.research.google.com/github/aehaf988/CB2330-portfolio/blob/main/Session01_getting_started.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
counts = [1204, 3310, 87, 412, 0, 26]
expressed = [c for c in counts if c >= 100]
def total_reads(counts):
  total = 0

  for value in counts:
      total = total + counts
  return total

assert total_reads([1, 2, 3, 4]) == 10, total_reads([1, 2, 3, 4])
assert total_reads([]) == 0, total_reads([])
print("A1 ok    total =", total_reads(counts))

def mean_reads(counts):
  total_reads = /(len(counts))

#def classify(counts, min_counts):
 # if counts == 0:
  #  return "dropout"
  #elif counts < min_count:
   # return "low"
#  else:
 #   return "expressed"


#n_expressed = 0


#n_expressed = n_expressed + 1
#mean_counts = total / n_expressed
#print(f"\n{n_expressed} of {len(genes)} genes expressed, mean count {mean_count:.1f}")

print(len(expressed), "of", len(counts), "genes expressed")
print("mean count", sum(expressed) / len(expressed))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_889/2126100606.py in <cell line: 0>()
#       7       total = total + counts
#       8   return total
# ----> 9 assert total_reads([1, 2, 3, 4]) == 10, total_reads([1, 2, 3, 4])
#      10 assert total_reads([]) == 0, total_reads([])
#      11 print("A1 ok    total =", total_reads(counts))
#
# /tmp/ipykernel_889/2126100606.py in total_reads(counts)
#       5
#       6   for value in counts:
# ----> 7       total = total + counts
#       8   return total
#       9 assert total_reads([1, 2, 3, 4]) == 10, total_reads([1, 2, 3, 4])
#
# TypeError: unsupported operand type(s) for +: 'int' and 'list'
